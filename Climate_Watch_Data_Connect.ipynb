# %% [markdown]
# <a href="https://colab.research.google.com/github/jped134/CattleVision/blob/master/Climate_Watch_Data_Connect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Goal: contribute here
# https://github.com/orgs/datacommonsorg/projects/10/views/1
#
# References:
# https://www.climatewatchdata.org/about/permissions
#
# https://colab.research.google.com/github/nestauk/im-tutorials/blob/3-ysi-tutorial/notebooks/APIs/API_tutorial.ipynb#scrollTo=gAJ7n8qeqQ3S

# %%
# %matplotlib inline

# %%
# Run this if you are using google colab (Download im_tutorial package)
# !git clone -b 3-ysi-tutorial https://github.com/nestauk/im-tutorials.git
# Out:
# Cloning into 'im-tutorials'...
# remote: Enumerating objects: 230, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 230 (delta 3), reused 3 (delta 3), pack-reused 224
# Receiving objects: 100% (230/230), 10.57 MiB | 11.84 MiB/s, done.
# Resolving deltas: 100% (96/96), done.

# %%
# install other packages we need
# !pip install ratelim pandas tenacity

# %%
import requests  # Import the requests library

# %%
# Query URL
url = ('https://www.climatewatchdata.org/api/v1/data/historical_emissions/data_sources'
      #sectors # sector_ids[] - view sector id at https://www.climatewatchdata.org/api/v1/data/historical_emissions/sectors
      #regions # regions[] - region ISO code 3 (ISO Codes for World and European Union (27) are WORLD and EUU, respectively)
      #start_year # start_year - Show results from this year onwards
      #end_year # end_year - Show results up to this year
      #sort_col # sort_col - column to sort the table by
      #sort_dir # sort_dir - sort direction (ASC or DESC)Mihttps://www.climatewatchdata.org/api/v1/data/historical_emissions/data_sourcesllion EUR
      )
#  All these parameters accept multiple values, separated by commas. Response is paginated. Pagination headers are in place.
print(url)

response = requests.get(url)  # Make a GET request to the URL

# Print status code (and associated text)
print(f"Request returned {response.status_code} : '{response.reason}'")

# Print data returned (parsing as JSON)
data_sources = response.json()  # Parse `response.text` into JSON
# NOTE: Could use print(response.json()) but this wouldn't be formatted nicely

#import pprint
#pp = pprint.PrettyPrinter(indent=1)
#pp.pprint(data_sources)
# Out:
# https://www.climatewatchdata.org/api/v1/data/historical_emissions/data_sources
# Request returned 200 : 'OK'

# %%
#data_sources['data']

# %%
import json
from pandas.io.json import json_normalize

df = json_normalize(data_sources, record_path =['data'])
#df = json_normalize(data_sources, record_path =['data'], meta = ['gas_ids','location_ids'])
df.head(3)
# Out:
# <ipython-input-64-1bc7142cc693>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(data_sources, record_path =['data'])
#     id           name    display_name  \
# 0  190  Climate Watch   Climate Watch
# 1  191            PIK             PIK
# 2  192      UNFCCC_AI  UNFCCC Annex I
#
#                                         location_ids  \
# 0  [1393, 1394, 1395, 1396, 1398, 1399, 1403, 140...
# 1  [1393, 1394, 1395, 1396, 1397, 1398, 1399, 140...
# 2  [1401, 1407, 1408, 1415, 1416, 1426, 1431, 144...
#
#                                           sector_ids  \
# 0  [2214, 2215, 2216, 2217, 2218, 2219, 2220, 222...
# 1               [2229, 2230, 2231, 2232, 2234, 2242]
# 2   [2244, 2245, 2248, 2249, 2250, 2251, 2252, 2253]
#
#                      gas_ids           slug
# 0  [441, 442, 443, 444, 445]  climate-watch
# 1  [442, 443, 444, 445, 446]            pik
# 2  [442, 443, 444, 447, 448]      unfccc_ai

# %%
# Query URL
url = ('https://www.climatewatchdata.org/api/v1/data/historical_emissions/'
      #sectors # sector_ids[] - view sector id at https://www.climatewatchdata.org/api/v1/data/historical_emissions/sectors
      #regions # regions[] - region ISO code 3 (ISO Codes for World and European Union (27) are WORLD and EUU, respectively)
      #start_year # start_year - Show results from this year onwards
      #end_year # end_year - Show results up to this year
      #sort_col # sort_col - column to sort the table by
      #sort_dir # sort_dir - sort direction (ASC or DESC)Mihttps://www.climatewatchdata.org/api/v1/data/historical_emissions/data_sourcesllion EUR
      )
#  All these parameters accept multiple values, separated by commas. Response is paginated. Pagination headers are in place.
print(url)

response = requests.get(url)  # Make a GET request to the URL

# Print status code (and associated text)
print(f"Request returned {response.status_code} : '{response.reason}'")

# Print data returned (parsing as JSON)
data_sources = response.json()  # Parse `response.text` into JSON
# NOTE: Could use print(response.json()) but this wouldn't be formatted nicely

#import pprint
#pp = pprint.PrettyPrinter(indent=1)
#pp.pprint(data_sources)
# Out:
# https://www.climatewatchdata.org/api/v1/data/historical_emissions/
# Request returned 200 : 'OK'

# %%
import json
from pandas.io.json import json_normalize

df = json_normalize(data_sources, record_path =['data'])
#df = json_normalize(data_sources, record_path =['data'], meta = ['gas_ids','location_ids'])
df.head(3)
# Out:
# <ipython-input-69-1bc7142cc693>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(data_sources, record_path =['data'])
#        id iso_code3 country data_source       sector       gas    unit  \
# 0  974933       ABW   Aruba         PIK  Agriculture       CH4  MtCO₂e
# 1  974934       ABW   Aruba         PIK  Agriculture  KYOTOGHG  MtCO₂e
# 2  974935       ABW   Aruba         PIK  Agriculture       N2O  MtCO₂e
#
#                                            emissions
# 0  [{'year': 1850, 'value': 0.0}, {'year': 1851, ...
# 1  [{'year': 1850, 'value': 0.0}, {'year': 1851, ...
# 2  [{'year': 1850, 'value': 0.0}, {'year': 1851, ...

# %%
#emission-pathways
# Query URL
url = ('https://data.emissionspathways.org/api/v1/data/emission_pathways'
      #sectors # sector_ids[] - view sector id at https://www.climatewatchdata.org/api/v1/data/historical_emissions/sectors
      #regions # regions[] - region ISO code 3 (ISO Codes for World and European Union (27) are WORLD and EUU, respectively)
      #start_year # start_year - Show results from this year onwards
      #end_year # end_year - Show results up to this year
      #sort_col # sort_col - column to sort the table by
      #sort_dir # sort_dir - sort direction (ASC or DESC)Mihttps://www.climatewatchdata.org/api/v1/data/historical_emissions/data_sourcesllion EUR
      )
#  All these parameters accept multiple values, separated by commas. Response is paginated. Pagination headers are in place.
print(url)

response = requests.get(url)  # Make a GET request to the URL

# Print status code (and associated text)
print(f"Request returned {response.status_code} : '{response.reason}'")

# Print data returned (parsing as JSON)
data_sources = response.json()  # Parse `response.text` into JSON
# NOTE: Could use print(response.json()) but this wouldn't be formatted nicely

import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(data_sources)
# Out:
# https://data.emissionspathways.org/api/v1/data/emission_pathways
# Request returned 200 : 'OK'
# {'data': [{'category': 'Energy',
#            'composite_name': 'Energy | Primary Energy by Fuel | Nuclear',
#            'definition': 'Primary energy from nuclear',
#            'emissions': [{'value': 21.92, 'year': 2025},
#                          {'value': 29.22, 'year': 2030},
#                          {'value': 36.96, 'year': 2035},
#                          {'value': 44.35, 'year': 2040},
#                          {'value': 13.65, 'year': 2011},
#                          {'value': 13.08, 'year': 2012},
#                          {'value': 14.44, 'year': 2020}],
#            'id': 1,
#            'indicator': 'Nuclear',
#            'iso_code2': None,
#            'location': 'Africa',
#            'model': 'International Energy Outlook',
#            'scenario': 'Reference (2016)',
#            'subcategory': 'Primary Energy by Fuel',
#            'unit': 'EJ/yr'},
# ...
